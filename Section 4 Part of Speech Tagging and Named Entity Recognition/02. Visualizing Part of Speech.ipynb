# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
from spacy import displacy

# %%
doc = nlp(u"let's write some sentenses.")

# %%
displacy.render(doc,style='dep',minify=True,jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a98bf0c71295451a975637aba435e818-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0"><tspan class="displacy-word" fill="currentColor" x="50">let</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0"><tspan class="displacy-word" fill="currentColor" x="225">'s</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0"><tspan class="displacy-word" fill="currentColor" x="400">write</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0"><tspan class="displacy-word" fill="currentColor" x="575">some</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0"><tspan class="displacy-word" fill="currentColor" x="750">sentenses.</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan></text><g class="displacy-arrow"><path class="displacy-arc" id="arrow-a98bf0c71295451a975637aba435e818-0-0" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-a98bf0c71295451a975637aba435e818-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath></text><path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-a98bf0c71295451a975637aba435e818-0-1" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-a98bf0c71295451a975637aba435e818-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath></text><path class="displacy-arrowhead" d="M400.0,179.0 L408.0,167.0 392.0,167.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-a98bf0c71295451a975637aba435e818-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-a98bf0c71295451a975637aba435e818-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath></text><path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-a98bf0c71295451a975637aba435e818-0-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-a98bf0c71295451a975637aba435e818-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath></text><path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/></g></svg>

# %%
options = {'compact':True,'color':'yellow','bg':'#87cefa'}
displacy.render(doc,style='dep',minify=True,jupyter=True,options = options)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6853efc4c28144259e02e0dc525ed73f-0" class="displacy" width="800" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: yellow; background: #87cefa; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0"><tspan class="displacy-word" fill="currentColor" x="50">let</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0"><tspan class="displacy-word" fill="currentColor" x="200">'s</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PRON</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0"><tspan class="displacy-word" fill="currentColor" x="350">write</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0"><tspan class="displacy-word" fill="currentColor" x="500">some</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0"><tspan class="displacy-word" fill="currentColor" x="650">sentenses.</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan></text><g class="displacy-arrow"><path class="displacy-arc" id="arrow-6853efc4c28144259e02e0dc525ed73f-0-0" stroke-width="2px" d="M212,152.0 212,127.0 347.0,127.0 347.0,152.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-6853efc4c28144259e02e0dc525ed73f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath></text><path class="displacy-arrowhead" d="M212,154.0 L208,146.0 216,146.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-6853efc4c28144259e02e0dc525ed73f-0-1" stroke-width="2px" d="M62,152.0 62,102.0 350.0,102.0 350.0,152.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-6853efc4c28144259e02e0dc525ed73f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath></text><path class="displacy-arrowhead" d="M350.0,154.0 L354.0,146.0 346.0,146.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-6853efc4c28144259e02e0dc525ed73f-0-2" stroke-width="2px" d="M512,152.0 512,127.0 647.0,127.0 647.0,152.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-6853efc4c28144259e02e0dc525ed73f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath></text><path class="displacy-arrowhead" d="M512,154.0 L508,146.0 516,146.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-6853efc4c28144259e02e0dc525ed73f-0-3" stroke-width="2px" d="M362,152.0 362,102.0 650.0,102.0 650.0,152.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-6853efc4c28144259e02e0dc525ed73f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath></text><path class="displacy-arrowhead" d="M650.0,154.0 L654.0,146.0 646.0,146.0" fill="currentColor"/></g></svg>

# %%
doc1 = nlp(u"This is the first sentence. Now le't write the second sentence. Do you have anything more to write? I don't think so.Let's print all the sentence token seprately.")
list(doc1.sents)
# Out:
# [This is the first sentence.,
#  Now le't write the second sentence.,
#  Do you have anything more to write?,
#  I don't think so.,
#  Let's print all the sentence token seprately.]

# %%
displacy.serve(doc1.sents,style='dep',port=5000, options={'compact':True,'color':'yellow','bg':'#87cefa'})
# Out:
# C:\Users\BibhuJha\Anaconda3\lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="18795854015c4ffdac83dc146b3f2241-0" class="displacy" width="800" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: yellow; background: #87cefa; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">sentence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18795854015c4ffdac83dc146b3f2241-0-0" stroke-width="2px" d="M62,227.0 62,202.0 194.0,202.0 194.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-18795854015c4ffdac83dc146b3f2241-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18795854015c4ffdac83dc146b3f2241-0-1" stroke-width="2px" d="M362,227.0 362,177.0 647.0,177.0 647.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-18795854015c4ffdac83dc146b3f2241-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,229.0 L358,221.0 366,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18795854015c4ffdac83dc146b3f2241-0-2" stroke-width="2px" d="M512,227.0 512,202.0 644.0,202.0 644.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-18795854015c4ffdac83dc146b3f2241-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,229.0 L508,221.0 516,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18795854015c4ffdac83dc146b3f2241-0-3" stroke-width="2px" d="M212,227.0 212,152.0 650.0,152.0 650.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-18795854015c4ffdac83dc146b3f2241-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,229.0 L654.0,221.0 646.0,221.0" fill="currentColor"/>
# </g>
# </svg>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="18795854015c4ffdac83dc146b3f2241-1" class="displacy" width="950" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: yellow; background: #87cefa; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">le't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">write</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">second</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">sentence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18795854015c4ffdac83dc146b3f2241-1-0" stroke-width="2px" d="M62,227.0 62,177.0 347.0,177.0 347.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-18795854015c4ffdac83dc146b3f2241-1-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18795854015c4ffdac83dc146b3f2241-1-1" stroke-width="2px" d="M212,227.0 212,202.0 344.0,202.0 344.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-18795854015c4ffdac83dc146b3f2241-1-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">expl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18795854015c4ffdac83dc146b3f2241-1-2" stroke-width="2px" d="M512,227.0 512,177.0 797.0,177.0 797.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-18795854015c4ffdac83dc146b3f2241-1-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,229.0 L508,221.0 516,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-18795854015c4ffdac83dc146b3f2241-1-3" stroke-width="2px" d="M662,227.0 662,202.0 794.0,202.0 794.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style=
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...

# %%
# http://127.0.0.1:5000/
